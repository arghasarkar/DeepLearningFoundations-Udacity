# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:60])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(len(vocab_to_int.keys()))
print(len(int_to_vocab.keys()))
print(len(int_words))
# Out:
# 63641
# 63641
# 16680599

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

from collections import Counter
import random
import math

counts = Counter(int_words)
freqs = {}
total_count = len(int_words)
print("Total size: {}".format(len(int_words)))
for word, count in counts.items():
    freqs[word] = count / total_count

threshold = 0.00006849873916398326
probs = {}
for word, freq in freqs.items():
    probs[word] = 1 - math.sqrt(threshold / freqs[word])


words_to_keep = []
for word in int_words:
    if (random.random() < (1 - probs[word])):
        words_to_keep.append(word)
        
print("Num of words being kept: {}".format(len(words_to_keep)))
print(words_to_keep[:100])
# Out:
# Total size: 16680599
# Num of words being kept: 7765400
# [5233, 3080, 194, 3133, 155, 10571, 27349, 854, 15067, 58112, 854, 3580, 190, 10712, 214, 1324, 454, 2731, 362, 3672, 708, 371, 97, 1423, 2757, 18, 567, 7088, 5233, 1052, 248, 44611, 2877, 792, 5233, 200, 602, 2621, 8983, 279, 4147, 6437, 4186, 362, 5233, 1137, 447, 1818, 4860, 6753, 7573, 1774, 566, 247, 11064, 7088, 270, 5948, 4861, 20299, 53721, 317, 25636, 527, 7573, 371, 258, 1206, 7573, 1576, 15200, 1774, 7088, 4860, 344, 160, 406, 5690, 4105, 1131, 4331, 1536, 567, 8117, 5233, 1407, 153, 7088, 2033, 1423, 8174, 6, 31, 4148, 948, 310, 30, 4778, 139, 2312]

# %%
train_words = words_to_keep

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    R = random.randint(1, window_size + 1)
    
    start = 0
    if (idx - R > 0):
        start = idx - R
    
    stop = idx + R
    
    # The targets words must be the ones excluding the current word
    words = set(words[start : idx] + words[idx + 1 : stop + 1])
    
    return list(words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name="inputs")
    labels = tf.placeholder(tf.int32, shape=[None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
size = n_vocab
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((size, n_embedding), -1, 1, name="embedding")) # Try again with normal
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((size, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(size))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w,
        softmax_b,
        labels,
        embed,
        n_sampled,
        size
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From D:\Applications\Python3\lib\site-packages\tensorflow\python\ops\nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-14-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.2687 0.0241 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.2503 0.0212 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.1992 0.0209 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.1335 0.0209 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.1264 0.0208 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 6.0594 0.0208 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.9798 0.0208 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.8376 0.0208 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.6627 0.0209 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5630 0.0208 sec/batch
# Nearest to four: ram, boards, can, density, providing, quiz, take, inventory,
# Nearest to has: locomotive, stromata, oates, folklorist, pataphysics, odor, overly, kingdom,
# Nearest to its: rudimentary, hinduism, responsible, decided, on, democracy, pasternak, corral,
# Nearest to one: tomb, d, light, neighborhood, seven, router, reginald, sens,
# Nearest to who: articulation, theistic, destined, glucose, food, inter, garnett, blurring,
# Nearest to was: returned, pie, the, authorial, while, map, heeled, them,
# Nearest to all: exercises, new, relations, synonyms, anderson, moods, dies, because,
# Nearest to into: arafura, and, required, hailstones, later, cornet, street, minos,
# Nearest to issue: ordinarily, lacked, korea, aachen, scrabble, class, significantly, jonesboro,
# Nearest to egypt: air, reluctant, withdrew, conference, infanticide, abolition, fronting, syrian,
# Nearest to police: trade, pursuing, shit, coffey, comical, championships, distinguished, sicily,
# Nearest to test: won, cultivation, telephones, aging, durrell, glutamate, giraud, savoie,
# Nearest to orthodox: bottle, arrested, fayed, proved, note, donates, gok, occasionaly,
# Nearest to san: overriding, release, quarterly, immunity, rz, early, skie, deliveries,
# Nearest to shows: rsi, occlusion, bald, confusingly, juden, partido, minna, recourse,
# Nearest to powers: invariant, coastguard, meteorologist, brentano, practitioners, padre, absorb, paso,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4575 0.0219 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3196 0.0207 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2851 0.0208 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1661 0.0209 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.0711 0.0208 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.0956 0.0207 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0183 0.0209 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.9933 0.0208 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9184 0.0208 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9254 0.0208 sec/batch
# Nearest to four: deputies, density, ram, boards, variants, quiz, reject, outcrops,
# Nearest to has: locomotive, stromata, comments, cultural, odor, kingdom, overly, whichever,
# Nearest to its: hinduism, rudimentary, decided, stands, democracy, italians, pasternak, responsible,
# Nearest to one: tomb, reginald, neighborhood, seven, whip, d, swept, hume,
# Nearest to who: theistic, food, articulation, destined, carries, blurring, glucose, inter,
# Nearest to was: pie, returned, heeled, included, stars, while, certificate, augusto,
# Nearest to all: synonyms, anderson, enterprise, exercises, jean, moods, residents, dies,
# Nearest to into: arafura, required, subset, saving, ellipsoids, great, shadow, wroc,
# Nearest to issue: lacked, significantly, ordinarily, korea, aachen, class, narrow, scrabble,
# Nearest to egypt: air, reluctant, withdrew, conference, abolition, syrian, islands, curve,
# Nearest to police: trade, pursuing, championships, distinguished, sicily, cohen, shit, wales,
# Nearest to test: telephones, won, cultivation, giraud, durrell, aging, glutamate, sexuality,
# Nearest to orthodox: bottle, arrested, incarnations, winds, donates, fayed, blankets, note,
# Nearest to san: overriding, immunity, quarterly, release, rz, corresponds, clipped, million,
# Nearest to shows: rsi, confusingly, bald, occlusion, inning, partido, beneficial, stayed,
# Nearest to powers: invariant, absorb, practitioners, extra, owners, hats, padre, example,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8890 0.0218 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8984 0.0208 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8730 0.0207 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8634 0.0208 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8359 0.0207 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8300 0.0208 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7779 0.0209 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8327 0.0207 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8015 0.0208 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7804 0.0208 sec/batch
# Nearest to four: density, deputies, outcrops, quiz, boards, ram, riboflavin, policemen,
# Nearest to has: locomotive, stromata, folklorist, comments, cultural, odor, whichever, pataphysics,
# Nearest to its: hinduism, rudimentary, regurgitated, alienate, stands, aristotle, decided, pasternak,
# Nearest to one: seven, d, reginald, tomb, whip, january, hume, zhukov,
# Nearest to who: theistic, articulation, blurring, destined, carries, appalachian, glucose, endeavors,
# Nearest to was: returned, pie, heeled, bounty, teleological, included, the, certificate,
# Nearest to all: synonyms, semiconductors, enterprise, moods, anderson, exercises, exercised, chanters,
# Nearest to into: arafura, subset, ellipsoids, required, saving, great, attacking, minos,
# Nearest to issue: ordinarily, scrabble, lacked, aachen, significantly, korea, truman, christians,
# Nearest to egypt: reluctant, air, conference, withdrew, syrian, abolition, sight, islands,
# Nearest to police: trade, pursuing, championships, coffey, pirated, cohen, distinguished, shit,
# Nearest to test: cultivation, telephones, won, sexuality, giraud, glutamate, durrell, filed,
# Nearest to orthodox: bottle, arrested, incarnations, verb, indians, donates, fayed, multipole,
# Nearest to san: overriding, quarterly, immunity, rz, clipped, bandleader, release, reaped,
# Nearest to shows: rsi, confusingly, occlusion, bald, partido, resolver, minna, beneficial,
# Nearest to powers: invariant, absorb, practitioners, meteorologist, hats, paso, owners, padre,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7929 0.0217 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7840 0.0209 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7574 0.0208 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7138 0.0208 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6846 0.0208 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6937 0.0209 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7052 0.0208 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7186 0.0208 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6710 0.0209 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6969 0.0209 sec/batch
# Nearest to four: outcrops, density, ram, policemen, wilhelm, riboflavin, deputies, quiz,
# Nearest to has: folklorist, locomotive, stromata, comments, tonga, pataphysics, cultural, odor,
# Nearest to its: hinduism, rudimentary, alienate, regurgitated, revivals, stands, democracy, on,
# Nearest to one: seven, reginald, january, tomb, d, harry, zhukov, arthur,
# Nearest to who: theistic, blurring, endeavors, destined, carries, articulation, reds, stylistically,
# Nearest to was: returned, pie, the, heeled, included, after, costello, bounty,
# Nearest to all: synonyms, semiconductors, moods, enterprise, exercised, anderson, exercises, because,
# Nearest to into: arafura, ellipsoids, required, subset, attacking, saving, copernicus, tarkovsky,
# Nearest to issue: ordinarily, scrabble, lacked, aachen, korea, truman, significantly, jonesboro,
# Nearest to egypt: reluctant, withdrew, conference, air, islands, infanticide, gendered, fronting,
# Nearest to police: trade, pursuing, coffey, pirated, championships, shit, cohen, wales,
# Nearest to test: cultivation, telephones, won, ticker, sexuality, giraud, filed, glutamate,
# Nearest to orthodox: bottle, church, incarnations, arrested, episcopal, donates, eftpos, catholic,
# Nearest to san: overriding, immunity, quarterly, rz, bandleader, clipped, reaped, release,
# Nearest to shows: rsi, occlusion, confusingly, partido, bald, recourse, minna, resolver,
# Nearest to powers: invariant, absorb, practitioners, duet, hats, meteorologist, coastguard, owners,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6932 0.0218 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6364 0.0207 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6363 0.0208 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6209 0.0208 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6129 0.0208 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6511 0.0211 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.6308 0.0210 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.6587 0.0209 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.6048 0.0209 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.6193 0.0208 sec/batch
# Nearest to four: outcrops, density, policemen, ram, deputies, boards, riboflavin, quiz,
# Nearest to has: folklorist, locomotive, stromata, whichever, overly, specializes, comments, pataphysics,
# Nearest to its: rudimentary, hinduism, alienate, regurgitated, stands, on, democracy, city,
# Nearest to one: reginald, seven, zhukov, january, whip, tomb, wil, hume,
# Nearest to who: theistic, blurring, endeavors, destined, reds, stylistically, carries, articulation,
# Nearest to was: returned, the, pie, heeled, after, eventually, included, costello,
# Nearest to all: synonyms, moods, semiconductors, realised, exercises, crows, because, portable,
# Nearest to into: arafura, ellipsoids, attacking, copernicus, saving, remanded, required, minos,
# Nearest to issue: ordinarily, scrabble, aachen, concordat, lacked, cantons, truman, jonesboro,
# Nearest to egypt: reluctant, withdrew, islands, infanticide, gendered, syrian, conference, abolition,
# Nearest to police: pursuing, trade, coffey, championships, pirated, wales, distinguished, encourages,
# Nearest to test: cultivation, telephones, ticker, won, animation, filed, sexuality, glutamate,
# Nearest to orthodox: church, bottle, catholic, episcopal, arrested, incarnations, och, donates,
# Nearest to san: immunity, overriding, quarterly, bandleader, rz, reaped, clipped, aratus,
# Nearest to shows: rsi, occlusion, confusingly, partido, recourse, bald, whale, tumble,
# Nearest to powers: invariant, coastguard, state, absorb, declared, meteorologist, duet, precincts,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.6116 0.0218 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.6542 0.0209 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.6038 0.0208 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.5898 0.0208 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.5243 0.0209 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.5766 0.0209 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.5222 0.0207 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5292 0.0208 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.4700 0.0208 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.4913 0.0208 sec/batch
# Nearest to four: seven, five, outcrops, riboflavin, wilhelm, one, zero, six,
# Nearest to has: folklorist, locomotive, stromata, whichever, cultural, overly, coexisted, pataphysics,
# Nearest to its: hinduism, alienate, rudimentary, regurgitated, stands, city, democracy, on,
# Nearest to one: seven, three, d, two, january, reginald, b, zero,
# Nearest to who: theistic, endeavors, destined, blurring, reds, husband, blavatsky, stylistically,
# Nearest to was: returned, the, heeled, after, pie, eventually, certificate, photographed,
# Nearest to all: synonyms, moods, realised, exercises, semiconductors, same, enterprise, think,
# Nearest to into: ellipsoids, attacking, arafura, remanded, copernicus, nis, tarkovsky, saving,
# Nearest to issue: ordinarily, scrabble, concordat, aachen, lacked, truman, cantons, jonesboro,
# Nearest to egypt: reluctant, syrian, withdrew, islands, infanticide, conference, planned, eradicated,
# Nearest to police: pursuing, trade, coffey, championships, pirated, against, spill, sicily,
# Nearest to test: cultivation, won, telephones, hound, ticker, animation, landlord, anus,
# Nearest to orthodox: church, catholic, bottle, incarnations, episcopal, christianity, christians, salvation,
# Nearest to san: quarterly, overriding, immunity, bandleader, rz, reaped, aratus, skie,
# Nearest to shows: rsi, occlusion, confusingly, partido, bald, recourse, corpuscular, whale,
# Nearest to powers: coastguard, state, invariant, declared, meteorologist, absorb, precincts, zog,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5364 0.0217 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.5570 0.0210 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.5849 0.0208 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.6150 0.0210 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.5550 0.0208 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.4380 0.0209 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5355 0.0208 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.5559 0.0208 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.5205 0.0207 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.5262 0.0208 sec/batch
# Nearest to four: outcrops, density, ram, policemen, seven, five, consummate, brewer,
# Nearest to has: stromata, folklorist, locomotive, coexisted, its, kuwaiti, iodide, whichever,
# Nearest to its: rudimentary, hinduism, alienate, regurgitated, stands, stouffer, weight, sharply,
# Nearest to one: seven, zhukov, wil, three, reginald, january, documentaries, reboot,
# Nearest to who: theistic, endeavors, destined, blurring, husband, chlorus, mature, catapults,
# Nearest to was: returned, heeled, eventually, after, the, he, pie, photographed,
# Nearest to all: synonyms, semiconductors, moods, same, chanters, realised, depot, minix,
# Nearest to into: ellipsoids, attacking, nis, tarkovsky, remanded, solidifies, saving, copernicus,
# Nearest to issue: ordinarily, scrabble, lacked, concordat, truman, aachen, jonesboro, cantons,
# Nearest to egypt: syrian, reluctant, withdrew, islands, eradicated, infanticide, gendered, cougar,
# Nearest to police: pursuing, coffey, pirated, trade, championships, zuma, distinguished, spill,
# Nearest to test: won, telephones, stimulates, hound, cultivation, animation, anus, ticker,
# Nearest to orthodox: church, catholic, bottle, episcopal, christians, salvation, christianity, incarnations,
# Nearest to san: quarterly, immunity, overriding, reaped, bandleader, rz, release, springs,
# Nearest to shows: rsi, occlusion, confusingly, partido, recourse, whale, morningside, onassis,
# Nearest to powers: coastguard, invariant, declared, state, zog, absorb, throttled, napoleonic,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.3582 0.0217 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.4971 0.0209 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.4469 0.0209 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.5036 0.0209 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.4933 0.0209 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.4688 0.0209 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.4846 0.0209 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.5142 0.0077 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3963 0.0211 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.4303 0.0212 sec/batch
# Nearest to four: outcrops, density, seven, ram, five, policemen, consummate, seconds,
# Nearest to has: locomotive, stromata, folklorist, coexisted, cultural, kuwaiti, whichever, iodide,
# Nearest to its: rudimentary, alienate, regurgitated, hinduism, sharply, stands, stouffer, freer,
# Nearest to one: seven, three, wil, reginald, two, zhukov, zero, turnbull,
# Nearest to who: theistic, husband, blurring, endeavors, chlorus, mature, blavatsky, destined,
# Nearest to was: returned, heeled, eventually, after, the, pie, he, soon,
# Nearest to all: synonyms, moods, semiconductors, think, ebm, realised, same, team,
# Nearest to into: ellipsoids, nis, tarkovsky, attacking, saving, aegean, solidifies, rfmf,
# Nearest to issue: ordinarily, scrabble, lacked, jonesboro, concordat, truman, objections, cantons,
# Nearest to egypt: syrian, reluctant, infanticide, eradicated, withdrew, gendered, islands, fronting,
# Nearest to police: pursuing, coffey, championships, pirated, distinguished, trade, encourages, zuma,
# Nearest to test: won, stimulates, telephones, animation, surge, hound, could, cultivation,
# Nearest to orthodox: church, catholic, episcopal, christians, christianity, bottle, salvation, religions,
# Nearest to san: immunity, overriding, quarterly, reaped, bandleader, springs, skie, moved,
# Nearest to shows: rsi, partido, confusingly, occlusion, resolver, onassis, recourse, whale,
# Nearest to powers: coastguard, zog, declared, invariant, state, appoints, absorb, throttled,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3942 0.0218 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.4041 0.0209 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4020 0.0210 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4058 0.0208 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3976 0.0210 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.4112 0.0208 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.4072 0.0209 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3927 0.0209 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.3148 0.0209 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.4321 0.0208 sec/batch
# Nearest to four: density, outcrops, seven, five, ram, mortality, consummate, zero,
# Nearest to has: locomotive, its, cultural, stromata, coexisted, term, whichever, folklorist,
# Nearest to its: rudimentary, regurgitated, stands, sharply, has, transparency, city, on,
# Nearest to one: seven, three, two, wil, zero, zhukov, turnbull, reginald,
# Nearest to who: theistic, destined, endeavors, husband, blurring, mature, chlorus, reds,
# Nearest to was: returned, after, heeled, eventually, mcintosh, soon, photographed, pie,
# Nearest to all: synonyms, semiconductors, team, exercises, ebm, yugoslavian, moods, realised,
# Nearest to into: ellipsoids, aegean, attacking, tarkovsky, nis, solidifies, saving, rfmf,
# Nearest to issue: ordinarily, scrabble, lacked, jonesboro, concordat, truman, aachen, objections,
# Nearest to egypt: syrian, reluctant, infanticide, withdrew, eradicated, gendered, islands, ethiopian,
# Nearest to police: pursuing, coffey, championships, pirated, distinguished, encourages, trade, zuma,
# Nearest to test: won, stimulates, surge, animation, hound, could, telephones, filed,
# Nearest to orthodox: catholic, church, episcopal, christians, christianity, salvation, bottle, catholics,
# Nearest to san: immunity, quarterly, overriding, springs, reaped, bandleader, diego, rz,
# Nearest to shows: occlusion, confusingly, rsi, partido, offense, resolver, whale, envied,
# Nearest to powers: coastguard, zog, appoints, invariant, declared, absorb, precincts, state,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.4222 0.0218 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.4005 0.0208 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 4.4004 0.0209 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 4.4024 0.0208 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 4.3955 0.0208 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 4.3392 0.0209 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 4.2318 0.0208 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 4.3951 0.0209 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 4.2952 0.0208 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 4.3629 0.0207 sec/batch
# Nearest to four: seven, density, outcrops, five, zero, three, est, ram,
# Nearest to has: locomotive, coexisted, its, cultural, suppressant, term, stromata, whichever,
# Nearest to its: regurgitated, sharply, stands, rudimentary, alienate, has, freer, democracy,
# Nearest to one: seven, three, two, zero, wil, reginald, january, turnbull,
# Nearest to who: theistic, endeavors, destined, husband, blavatsky, reds, mature, stylistically,
# Nearest to was: returned, heeled, eventually, after, mcintosh, pie, he, soon,
# Nearest to all: synonyms, semiconductors, innately, ebm, same, realised, yugoslavian, edwardian,
# Nearest to into: ellipsoids, tarkovsky, nis, rfmf, aegean, attacking, solidifies, arafura,
# Nearest to issue: ordinarily, scrabble, jonesboro, lacked, concordat, truman, objections, cantons,
# Nearest to egypt: syrian, reluctant, eradicated, infanticide, withdrew, tonga, gendered, fronting,
# Nearest to police: pursuing, coffey, championships, pirated, trade, distinguished, encourages, debuts,
# Nearest to test: won, surge, stimulates, hound, haki, animation, anus, perforated,
# Nearest to orthodox: catholic, church, episcopal, christians, salvation, catholics, christianity, churches,
# Nearest to san: immunity, springs, quarterly, diego, overriding, reaped, bandleader, clipped,
# Nearest to shows: confusingly, occlusion, rsi, whale, resolver, partido, megawatt, balalaika,
# Nearest to powers: coastguard, appoints, zog, invariant, declared, basler, grapefruit, precincts,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 4.3429 0.0216 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 4.3633 0.0208 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 4.3499 0.0208 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 4.3677 0.0209 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 4.3225 0.0209 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 4.3810 0.0207 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 4.2965 0.0208 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 4.3184 0.0207 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 4.3428 0.0209 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 4.4021 0.0209 sec/batch
# Nearest to four: seven, five, zero, ram, three, outcrops, one, six,
# Nearest to has: coexisted, term, siliceous, locomotive, pataphysics, suggests, whichever, cultural,
# Nearest to its: regurgitated, alienate, stands, rudimentary, hinduism, freer, sharply, stouffer,
# Nearest to one: seven, three, two, zero, reginald, wil, four, january,
# Nearest to who: theistic, husband, endeavors, chlorus, loud, unprofessional, blavatsky, stylistically,
# Nearest to was: returned, heeled, eventually, after, mcintosh, he, soon, had,
# Nearest to all: synonyms, innately, ebm, semiconductors, team, realised, edwardian, same,
# Nearest to into: ellipsoids, solidifies, tarkovsky, rfmf, nis, attacking, clinched, remanded,
# Nearest to issue: ordinarily, scrabble, concordat, jonesboro, lacked, truman, cantons, objections,
# Nearest to egypt: syrian, reluctant, eradicated, infanticide, tonga, vocations, fronting, ethiopian,
# Nearest to police: pursuing, coffey, championships, pirated, ccc, udall, rassemblement, dystopic,
# Nearest to test: won, surge, stimulates, animation, haki, filed, colossus, anus,
# Nearest to orthodox: catholic, episcopal, church, catholics, creed, salvation, orthodoxy, churches,
# Nearest to san: immunity, diego, springs, quarterly, overriding, bandleader, reaped, canaria,
# Nearest to shows: confusingly, occlusion, resolver, rsi, balalaika, hosts, partido, megawatt,
# Nearest to powers: coastguard, invariant, zog, appoints, basler, declared, grapefruit, southerners,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 4.3621 0.0217 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 4.2875 0.0209 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 4.2945 0.0209 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 4.3339 0.0210 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 4.3352 0.0214 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 4.3810 0.0211 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.2890 0.0209 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.3305 0.0209 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.3408 0.0207 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.3129 0.0208 sec/batch
# Nearest to four: seven, five, zero, three, one, six, nine, density,
# Nearest to has: coexisted, its, whichever, term, cultural, locomotive, suppressant, is,
# Nearest to its: regurgitated, rudimentary, alienate, sharply, has, stands, freer, democracy,
# Nearest to one: seven, three, two, zero, four, reginald, kiefer, turnbull,
# Nearest to who: theistic, husband, chlorus, blavatsky, endeavors, loud, mecha, unprofessional,
# Nearest to was: returned, eventually, after, heeled, mcintosh, he, soon, had,
# Nearest to all: synonyms, realised, innately, iditarod, ebm, think, semiconductors, edwardian,
# Nearest to into: ellipsoids, solidifies, tarkovsky, remanded, rfmf, nis, clinched, widgery,
# Nearest to issue: ordinarily, concordat, scrabble, jonesboro, lacked, objections, truman, cantons,
# Nearest to egypt: syrian, tonga, eradicated, infanticide, reluctant, fronting, ceylon, northernmost,
# Nearest to police: pursuing, coffey, championships, udall, distinguished, ccc, pirated, dystopic,
# Nearest to test: won, animation, surge, stimulates, haki, colossus, filed, anus,
# Nearest to orthodox: episcopal, catholic, church, orthodoxy, churches, catholics, sacramental, creed,
# Nearest to san: immunity, diego, quarterly, springs, overriding, canaria, bandleader, electroacoustic,
# Nearest to shows: confusingly, occlusion, resolver, rsi, balalaika, megawatt, partido, hosts,
# Nearest to powers: coastguard, invariant, zog, appoints, southerners, nobles, declared, basler,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.3375 0.0217 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.2418 0.0209 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.3543 0.0209 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.3191 0.0208 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.3695 0.0207 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.3327 0.0208 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.3104 0.0208 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.3204 0.0208 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.3520 0.0209 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.3178 0.0208 sec/batch
# Nearest to four: seven, five, zero, three, one, six, nine, two,
# Nearest to has: coexisted, its, whichever, term, is, suppressant, pataphysics, suggests,
# Nearest to its: regurgitated, alienate, transparency, has, freer, sharply, democracy, reabsorption,
# Nearest to one: seven, three, two, zero, four, reginald, january, turnbull,
# Nearest to who: theistic, husband, blavatsky, chlorus, sachsenhausen, stylistically, marry, destined,
# Nearest to was: returned, eventually, after, he, soon, heeled, had, the,
# Nearest to all: synonyms, realised, innately, ebm, same, yugoslavian, semiconductors, iditarod,
# Nearest to into: ellipsoids, tarkovsky, aegean, remanded, solidifies, widgery, rfmf, attacking,
# Nearest to issue: ordinarily, scrabble, concordat, jonesboro, cantons, objections, lacked, significantly,
# Nearest to egypt: syrian, eradicated, infanticide, withdrew, reluctant, tonga, cougar, papandreou,
# Nearest to police: pursuing, coffey, championships, armed, udall, ccc, distinguished, npt,
# Nearest to test: won, animation, stimulates, surge, anus, haki, telephones, colossus,
# Nearest to orthodox: episcopal, catholic, church, orthodoxy, sacramental, salvation, creed, catholics,
# Nearest to san: immunity, diego, overriding, canaria, springs, electroacoustic, bandleader, quarterly,
# Nearest to shows: confusingly, hosts, resolver, occlusion, megawatt, balalaika, rsi, rfcs,
# Nearest to powers: coastguard, invariant, zog, appoints, declared, state, nobles, southerners,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.3361 0.0218 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.2477 0.0210 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.2867 0.0209 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.2833 0.0208 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.2268 0.0208 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.3439 0.0209 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.2242 0.0209 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.2357 0.0208 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.3470 0.0208 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.3325 0.0208 sec/batch
# Nearest to four: seven, five, zero, three, one, six, nine, two,
# Nearest to has: coexisted, its, term, is, paracompact, suppressant, cultural, pataphysics,
# Nearest to its: alienate, transparency, has, regurgitated, freer, stands, sharply, democracy,
# Nearest to one: seven, three, two, zero, four, january, six, wil,
# Nearest to who: theistic, chlorus, endeavors, husband, blavatsky, invitation, stealing, disorganized,
# Nearest to was: returned, eventually, he, after, soon, had, heeled, office,
# Nearest to all: realised, ebm, synonyms, innately, think, same, the, edwardian,
# Nearest to into: ellipsoids, tarkovsky, clinched, remanded, widgery, aegean, olomouc, solidifies,
# Nearest to issue: ordinarily, concordat, scrabble, cantons, jonesboro, objections, lacked, truman,
# Nearest to egypt: syrian, infanticide, eradicated, papandreou, cougar, vocations, reluctant, tonga,
# Nearest to police: pursuing, championships, coffey, udall, distinguished, armed, papillon, dunkirk,
# Nearest to test: won, surge, stimulates, animation, anus, potemkin, murakami, zuse,
# Nearest to orthodox: episcopal, sacramental, salvation, catholic, church, churches, orthodoxy, ecusa,
# Nearest to san: diego, immunity, canaria, overriding, springs, bandleader, electroacoustic, klaviertrio,
# Nearest to shows: confusingly, balalaika, occlusion, resolver, megawatt, hosts, onassis, rsi,
# Nearest to powers: coastguard, invariant, zog, uncial, southerners, throttled, basler, appoints,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.4016 0.0217 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.4013 0.0207 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.3134 0.0209 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.2059 0.0209 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.2895 0.0208 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.3093 0.0207 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.3385 0.0208 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.2708 0.0208 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.1085 0.0209 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.3265 0.0208 sec/batch
# Nearest to four: seven, five, zero, three, two, one, nine, six,
# Nearest to has: its, coexisted, is, suppressant, cultural, term, although, been,
# Nearest to its: has, transparency, regurgitated, rudimentary, alienate, freer, sharply, stands,
# Nearest to one: seven, two, three, zero, four, six, five, eight,
# Nearest to who: theistic, endeavors, chlorus, stealing, withheld, husband, sachsenhausen, montezuma,
# Nearest to was: returned, eventually, soon, after, he, had, heeled, mcintosh,
# Nearest to all: synonyms, ebm, realised, innately, yugoslavian, edwardian, iditarod, same,
# Nearest to into: ellipsoids, widgery, rfmf, solidifies, tarkovsky, clinched, olomouc, aegean,
# Nearest to issue: ordinarily, concordat, scrabble, cantons, lacked, jonesboro, objections, truman,
# Nearest to egypt: syrian, infanticide, eradicated, papandreou, reluctant, cougar, tonga, fronting,
# Nearest to police: pursuing, armed, papillon, coffey, udall, championships, distinguished, petrograd,
# Nearest to test: won, stimulates, surge, animation, anus, potemkin, zuse, geelong,
# Nearest to orthodox: episcopal, sacramental, catholic, bottle, orthodoxy, ceti, church, pontryagin,
# Nearest to san: diego, immunity, springs, canaria, jose, overriding, antonio, klaviertrio,
# Nearest to shows: confusingly, hosts, balalaika, occlusion, megawatt, resolver, rfcs, showcase,
# Nearest to powers: coastguard, invariant, zog, southerners, appoints, uncial, nobles, throttled,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.2255 0.0217 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.2836 0.0208 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.2753 0.0208 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.2979 0.0209 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.3302 0.0208 sec/batch
# Epoch 3/10 Iteration: 15600 Avg. Training loss: 4.2994 0.0150 sec/batch
# Epoch 3/10 Iteration: 15700 Avg. Training loss: 4.2375 0.0209 sec/batch
# Epoch 3/10 Iteration: 15800 Avg. Training loss: 4.2560 0.0209 sec/batch
# Epoch 3/10 Iteration: 15900 Avg. Training loss: 4.2495 0.0209 sec/batch
# Epoch 3/10 Iteration: 16000 Avg. Training loss: 4.2205 0.0209 sec/batch
# Nearest to four: seven, five, zero, one, three, two, six, nine,
# Nearest to has: its, coexisted, suppressant, is, although, cultural, term, suggests,
# Nearest to its: has, transparency, stands, sharply, freer, regurgitated, hypnotherapists, aristotle,
# Nearest to one: seven, three, two, zero, four, six, five, eight,
# Nearest to who: theistic, endeavors, chlorus, invitation, husband, blavatsky, sachsenhausen, testaments,
# Nearest to was: returned, eventually, he, after, had, soon, first, the,
# Nearest to all: synonyms, ebm, innately, realised, the, yugoslavian, iditarod, measurable,
# Nearest to into: ellipsoids, solidifies, tarkovsky, rfmf, aegean, widgery, stamping, clinched,
# Nearest to issue: ordinarily, scrabble, concordat, cantons, jonesboro, lacked, objections, truman,
# Nearest to egypt: syrian, infanticide, eradicated, vocations, papandreou, tonga, fronting, reluctant,
# Nearest to police: pursuing, papillon, coffey, udall, armed, petrograd, distinguished, championships,
# Nearest to test: won, stimulates, surge, potemkin, anus, animation, excursion, murakami,
# Nearest to orthodox: episcopal, sacramental, catholic, church, bottle, salvation, orthodoxy, churches,
# Nearest to san: immunity, diego, springs, canaria, overriding, antonio, jose, francisco,
# Nearest to shows: confusingly, occlusion, resolver, hosts, balalaika, showcase, rfcs, megawatt,
# Nearest to powers: coastguard, invariant, zog, southerners, uncial, appoints, basler, nobles,
# Epoch 3/10 Iteration: 16100 Avg. Training loss: 4.2424 0.0219 sec/batch
# Epoch 3/10 Iteration: 16200 Avg. Training loss: 4.2575 0.0208 sec/batch
# Epoch 3/10 Iteration: 16300 Avg. Training loss: 4.1978 0.0210 sec/batch
# Epoch 3/10 Iteration: 16400 Avg. Training loss: 4.2680 0.0208 sec/batch
# Epoch 3/10 Iteration: 16500 Avg. Training loss: 4.2333 0.0209 sec/batch
# Epoch 3/10 Iteration: 16600 Avg. Training loss: 4.2469 0.0209 sec/batch
# Epoch 3/10 Iteration: 16700 Avg. Training loss: 4.1503 0.0207 sec/batch
# Epoch 3/10 Iteration: 16800 Avg. Training loss: 4.2768 0.0208 sec/batch
# Epoch 3/10 Iteration: 16900 Avg. Training loss: 4.2660 0.0208 sec/batch
# Epoch 3/10 Iteration: 17000 Avg. Training loss: 4.2848 0.0208 sec/batch
# Nearest to four: seven, five, three, zero, one, six, two, nine,
# Nearest to has: its, coexisted, been, although, is, having, term, suppressant,
# Nearest to its: has, stands, sharply, transparency, freer, regurgitated, alienate, original,
# Nearest to one: seven, three, two, zero, four, six, eight, five,
# Nearest to who: theistic, endeavors, unprofessional, invitation, husband, reds, marry, parable,
# Nearest to was: returned, eventually, after, had, soon, first, he, office,
# Nearest to all: synonyms, innately, ebm, team, realised, yugoslavian, the, iditarod,
# Nearest to into: ellipsoids, solidifies, rfmf, tarkovsky, stamping, widgery, aegean, end,
# Nearest to issue: ordinarily, scrabble, concordat, jonesboro, cantons, ripper, lacked, objections,
# Nearest to egypt: syrian, infanticide, eradicated, papandreou, fronting, vocations, withdrew, cougar,
# Nearest to police: pursuing, papillon, udall, petrograd, coffey, zuma, distinguished, dystopic,
# Nearest to test: won, stimulates, surge, potemkin, intercontinental, murakami, anus, geelong,
# Nearest to orthodox: episcopal, sacramental, catholic, church, churches, salvation, catholics, orthodoxy,
# Nearest to san: diego, immunity, jose, springs, canaria, antonio, francisco, overriding,
# Nearest to shows: confusingly, occlusion, showcase, resolver, hosts, rfcs, balalaika, megawatt,
# Nearest to powers: coastguard, invariant, zog, appoints, southerners, uncial, parallel, basler,
# Epoch 3/10 Iteration: 17100 Avg. Training loss: 4.2557 0.0217 sec/batch
# Epoch 3/10 Iteration: 17200 Avg. Training loss: 4.2802 0.0210 sec/batch
# Epoch 3/10 Iteration: 17300 Avg. Training loss: 4.2368 0.0207 sec/batch
# Epoch 3/10 Iteration: 17400 Avg. Training loss: 4.1738 0.0207 sec/batch
# Epoch 3/10 Iteration: 17500 Avg. Training loss: 4.1297 0.0208 sec/batch
# Epoch 3/10 Iteration: 17600 Avg. Training loss: 4.2214 0.0209 sec/batch
# Epoch 3/10 Iteration: 17700 Avg. Training loss: 4.1912 0.0209 sec/batch
# Epoch 3/10 Iteration: 17800 Avg. Training loss: 4.2097 0.0209 sec/batch
# Epoch 3/10 Iteration: 17900 Avg. Training loss: 4.1642 0.0207 sec/batch
# Epoch 3/10 Iteration: 18000 Avg. Training loss: 4.2360 0.0209 sec/batch
# Nearest to four: seven, five, three, zero, one, two, six, nine,
# Nearest to has: its, been, coexisted, although, is, having, suppressant, term,
# Nearest to its: has, sharply, regurgitated, stands, sunos, freer, transparency, hinduism,
# Nearest to one: seven, three, two, zero, four, six, five, eight,
# Nearest to who: theistic, endeavors, unprofessional, invitation, withheld, husband, malleson, stealing,
# Nearest to was: eventually, returned, after, soon, had, he, first, mcintosh,
# Nearest to all: synonyms, innately, yugoslavian, ebm, the, measurable, realised, iditarod,
# Nearest to into: ellipsoids, solidifies, rfmf, tarkovsky, stamping, clinched, end, customizing,
# Nearest to issue: ordinarily, scrabble, cantons, concordat, jonesboro, lacked, gastroenterology, rubbish,
# Nearest to egypt: syrian, eradicated, fronting, infanticide, cougar, papandreou, tonga, withdrew,
# Nearest to police: pursuing, papillon, distinguished, petrograd, udall, armed, zuma, dystopic,
# Nearest to test: won, stimulates, surge, anus, potemkin, wff, murakami, animation,
# Nearest to orthodox: episcopal, sacramental, catholic, churches, salvation, christians, catholics, church,
# Nearest to san: diego, immunity, jose, springs, canaria, francisco, santa, california,
# Nearest to shows: confusingly, resolver, rfcs, occlusion, hosts, showcase, beauties, megawatt,
# Nearest to powers: coastguard, invariant, zog, appoints, southerners, nobles, sturm, basler,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 4.2295 0.0218 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 4.2276 0.0209 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 4.2236 0.0210 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 4.2037 0.0209 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 4.2147 0.0209 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 4.2049 0.0209 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 4.2624 0.0209 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 4.2601 0.0210 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 4.1979 0.0214 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 4.2095 0.0210 sec/batch
# Nearest to four: seven, five, three, six, one, two, zero, nine,
# Nearest to has: its, coexisted, been, is, although, having, suggests, term,
# Nearest to its: has, transparency, sunos, stands, freer, sharply, regurgitated, alienate,
# Nearest to one: seven, two, three, zero, four, six, five, eight,
# Nearest to who: unprofessional, theistic, endeavors, invitation, husband, nigel, montezuma, withheld,
# Nearest to was: eventually, returned, after, had, soon, he, mcintosh, office,
# Nearest to all: synonyms, the, realised, innately, ebm, iditarod, thus, measurable,
# Nearest to into: ellipsoids, solidifies, stamping, rfmf, tarkovsky, clinched, end, customizing,
# Nearest to issue: ordinarily, cantons, concordat, jonesboro, scrabble, magazines, mixtape, ripper,
# Nearest to egypt: syrian, fronting, papandreou, tonga, infanticide, eradicated, ethiopian, cougar,
# Nearest to police: pursuing, udall, distinguished, papillon, petrograd, armed, ccc, zuma,
# Nearest to test: stimulates, won, surge, anus, wff, murakami, potemkin, minimized,
# Nearest to orthodox: episcopal, sacramental, catholic, churches, catholics, orthodoxy, christians, church,
# Nearest to san: diego, immunity, jose, canaria, springs, francisco, antonio, santa,
# Nearest to shows: confusingly, resolver, rfcs, hosts, showcase, occlusion, beauties, rsi,
# Nearest to powers: coastguard, invariant, zog, appoints, southerners, nobles, precincts, basler,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 4.1836 0.0217 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 4.2312 0.0210 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 4.2180 0.0208 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 4.1843 0.0208 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 4.2183 0.0209 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 4.2372 0.0208 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 4.1742 0.0207 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 4.2321 0.0207 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 4.1990 0.0208 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 4.1630 0.0208 sec/batch
# Nearest to four: seven, five, three, zero, one, two, six, nine,
# Nearest to has: its, been, coexisted, is, having, although, suggests, term,
# Nearest to its: has, transparency, stands, freer, alienate, sharply, sunos, rudimentary,
# Nearest to one: seven, two, three, zero, four, six, eight, five,
# Nearest to who: invitation, withheld, theistic, endeavors, montezuma, unprofessional, disorganized, detainee,
# Nearest to was: eventually, returned, after, had, he, soon, first, mcintosh,
# Nearest to all: innately, synonyms, realised, yugoslavian, ebm, fractional, iditarod, thus,
# Nearest to into: ellipsoids, solidifies, clinched, stamping, end, tarkovsky, rfmf, enacting,
# Nearest to issue: ordinarily, cantons, jonesboro, concordat, magazines, scrabble, ripper, rubbish,
# Nearest to egypt: syrian, fronting, tonga, papandreou, infanticide, ethiopian, cougar, eradicated,
# Nearest to police: armed, udall, distinguished, pursuing, papillon, petrograd, criminal, dunkirk,
# Nearest to test: won, stimulates, surge, potemkin, geelong, wff, murakami, anus,
# Nearest to orthodox: episcopal, sacramental, churches, orthodoxy, ecusa, catholic, creed, church,
# Nearest to san: diego, immunity, jose, francisco, canaria, antonio, santa, california,
# Nearest to shows: confusingly, resolver, showcase, rfcs, hosts, occlusion, beauties, ccg,
# Nearest to powers: invariant, coastguard, zog, appoints, southerners, state, precincts, basler,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 4.2139 0.0219 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 4.2149 0.0209 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 4.2768 0.0209 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 4.1566 0.0210 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 4.2358 0.0209 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 4.2126 0.0210 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 4.2218 0.0209 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 4.2359 0.0209 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 4.2461 0.0208 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 4.1390 0.0208 sec/batch
# Nearest to four: seven, five, three, zero, two, one, six, nine,
# Nearest to has: its, been, is, coexisted, having, although, suppressant, whichever,
# Nearest to its: has, transparency, stands, alienate, sharply, the, in, freer,
# Nearest to one: seven, three, two, zero, four, six, eight, five,
# Nearest to who: theistic, withheld, invitation, disorganized, chlorus, endeavors, hazing, stealing,
# Nearest to was: eventually, after, returned, had, he, soon, first, the,
# Nearest to all: yugoslavian, innately, the, synonyms, realised, ebm, thus, touched,
# Nearest to into: ellipsoids, end, clinched, solidifies, tarkovsky, and, stamping, rfmf,
# Nearest to issue: ordinarily, cantons, concordat, jonesboro, magazines, ratification, on, mlas,
# Nearest to egypt: syrian, fronting, tonga, papandreou, sinai, infanticide, cougar, withdrew,
# Nearest to police: armed, distinguished, udall, papillon, pursuing, rassemblement, dunkirk, championships,
# Nearest to test: won, stimulates, geelong, surge, wff, potemkin, murakami, anus,
# Nearest to orthodox: sacramental, episcopal, churches, ecusa, orthodoxy, pontryagin, creed, ceti,
# Nearest to san: diego, immunity, jose, francisco, canaria, santa, antonio, california,
# Nearest to shows: confusingly, resolver, showcase, rfcs, occlusion, hosts, beauties, ccg,
# Nearest to powers: coastguard, invariant, zog, appoints, southerners, state, nobles, oscillates,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 4.1683 0.0218 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 4.1996 0.0208 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 4.2016 0.0210 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 4.1770 0.0210 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 4.1223 0.0209 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 4.2013 0.0208 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 4.2848 0.0210 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 4.2394 0.0208 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 4.2879 0.0209 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 4.2733 0.0208 sec/batch
# Nearest to four: seven, five, zero, three, one, two, six, nine,
# Nearest to has: been, its, is, coexisted, although, having, have, suppressant,
# Nearest to its: has, alienate, freer, transparency, stands, pki, sharply, aristotle,
# Nearest to one: seven, two, three, zero, four, six, eight, five,
# Nearest to who: withheld, disorganized, theistic, invitation, stealing, forsyth, endeavors, montezuma,
# Nearest to was: eventually, after, he, returned, had, first, a, soon,
# Nearest to all: ebm, the, yugoslavian, innately, realised, touched, thus, everlasting,
# Nearest to into: ellipsoids, clinched, tarkovsky, end, solidifies, stamping, rfmf, customizing,
# Nearest to issue: ordinarily, cantons, concordat, magazines, on, rubbish, jonesboro, ratification,
# Nearest to egypt: syrian, fronting, papandreou, infanticide, tonga, vocations, eradicated, sinai,
# Nearest to police: udall, distinguished, armed, papillon, dunkirk, rassemblement, pursuing, cartooning,
# Nearest to test: won, geelong, stimulates, surge, potemkin, anus, postulated, wff,
# Nearest to orthodox: sacramental, episcopal, ecusa, ceti, orthodoxy, pontryagin, churches, associations,
# Nearest to san: diego, immunity, jose, francisco, canaria, antonio, california, santa,
# Nearest to shows: confusingly, showcase, resolver, rfcs, beauties, balalaika, ccg, occlusion,
# Nearest to powers: coastguard, invariant, zog, southerners, oscillates, uncial, appoints, nobles,
# Epoch 3/10 Iteration: 22100 Avg. Training loss: 4.1191 0.0218 sec/batch
# Epoch 3/10 Iteration: 22200 Avg. Training loss: 4.2046 0.0208 sec/batch
# Epoch 3/10 Iteration: 22300 Avg. Training loss: 4.1962 0.0208 sec/batch
# Epoch 3/10 Iteration: 22400 Avg. Training loss: 4.1981 0.0206 sec/batch
# ...
# Epoch 9/10 Iteration: 69700 Avg. Training loss: 4.0443 0.0208 sec/batch
# Epoch 9/10 Iteration: 69800 Avg. Training loss: 4.0745 0.0209 sec/batch
# Epoch 10/10 Iteration: 69900 Avg. Training loss: 4.1068 0.0035 sec/batch
# Epoch 10/10 Iteration: 70000 Avg. Training loss: 4.0606 0.0208 sec/batch
# Nearest to four: three, one, five, six, two, seven, zero, nine,
# Nearest to has: been, is, since, its, have, although, recently, it,
# Nearest to its: has, the, is, it, an, a, of, s,
# Nearest to one: nine, four, seven, three, two, six, eight, five,
# Nearest to who: whom, people, wftu, unmibh, had, members, themselves, by,
# Nearest to was: had, later, first, after, a, he, as, became,
# Nearest to all: are, and, separate, other, most, their, together, of,
# Nearest to into: out, entered, through, then, which, from, a, and,
# Nearest to issue: issues, accept, pg, compromise, whether, january, since, magazine,
# Nearest to egypt: sinai, pressing, papandreou, ethiopian, caesarion, egyptian, fronting, sucessful,
# Nearest to police: rassemblement, gestapo, armed, officers, paramilitary, militare, papillon, udall,
# Nearest to test: tests, testing, matches, intercontinental, rounders, postulated, ban, prentice,
# Nearest to orthodox: orthodoxy, blankets, ceti, dist, pontryagin, hussar, eastern, mmorpg,
# Nearest to san: francisco, diego, bernardino, california, jose, chargers, antonio, rectal,
# Nearest to shows: show, shown, sketch, ccm, showcase, sitcoms, mostly, guest,
# Nearest to powers: executive, raeder, othon, averting, historicism, lafayette, heading, cigars,
# Epoch 10/10 Iteration: 70100 Avg. Training loss: 4.0831 0.0218 sec/batch
# Epoch 10/10 Iteration: 70200 Avg. Training loss: 4.0331 0.0209 sec/batch
# Epoch 10/10 Iteration: 70300 Avg. Training loss: 4.0746 0.0209 sec/batch
# Epoch 10/10 Iteration: 70400 Avg. Training loss: 4.0178 0.0211 sec/batch
# Epoch 10/10 Iteration: 70500 Avg. Training loss: 4.0686 0.0210 sec/batch
# Epoch 10/10 Iteration: 70600 Avg. Training loss: 4.0361 0.0209 sec/batch
# Epoch 10/10 Iteration: 70700 Avg. Training loss: 4.0450 0.0208 sec/batch
# Epoch 10/10 Iteration: 70800 Avg. Training loss: 4.0579 0.0208 sec/batch
# Epoch 10/10 Iteration: 70900 Avg. Training loss: 4.0511 0.0209 sec/batch
# Epoch 10/10 Iteration: 71000 Avg. Training loss: 3.9476 0.0208 sec/batch
# Nearest to four: three, one, five, six, two, seven, nine, zero,
# Nearest to has: been, is, its, since, have, although, it, recently,
# Nearest to its: has, the, is, a, it, of, an, s,
# Nearest to one: four, three, nine, seven, two, six, eight, five,
# Nearest to who: whom, people, themselves, wftu, had, by, kidnapped, unmibh,
# Nearest to was: had, later, first, a, after, became, he, as,
# Nearest to all: are, and, separate, other, their, most, only, of,
# Nearest to into: then, entered, out, through, finally, which, a, and,
# Nearest to issue: issues, accept, january, pg, since, uncomfortable, compromise, talia,
# Nearest to egypt: sinai, egyptian, pressing, papandreou, caesarion, ethiopian, geezer, tyre,
# Nearest to police: rassemblement, gestapo, armed, officers, petrograd, udall, paramilitary, papillon,
# Nearest to test: tests, testing, matches, intercontinental, rounders, postulated, ban, prentice,
# Nearest to orthodox: orthodoxy, blankets, ceti, eastern, hussar, dist, pontryagin, arrested,
# Nearest to san: francisco, diego, california, bernardino, jose, chargers, antonio, rectal,
# Nearest to shows: show, shown, showcase, ccm, sketch, pisano, trakai, unassigned,
# Nearest to powers: executive, othon, raeder, historicism, authority, averting, lafayette, heading,
# Epoch 10/10 Iteration: 71100 Avg. Training loss: 4.0300 0.0217 sec/batch
# Epoch 10/10 Iteration: 71200 Avg. Training loss: 4.0718 0.0207 sec/batch
# Epoch 10/10 Iteration: 71300 Avg. Training loss: 4.0473 0.0209 sec/batch
# Epoch 10/10 Iteration: 71400 Avg. Training loss: 4.0545 0.0209 sec/batch
# Epoch 10/10 Iteration: 71500 Avg. Training loss: 4.0695 0.0208 sec/batch
# Epoch 10/10 Iteration: 71600 Avg. Training loss: 4.1168 0.0208 sec/batch
# Epoch 10/10 Iteration: 71700 Avg. Training loss: 3.9890 0.0208 sec/batch
# Epoch 10/10 Iteration: 71800 Avg. Training loss: 3.8948 0.0209 sec/batch
# Epoch 10/10 Iteration: 71900 Avg. Training loss: 4.0100 0.0209 sec/batch
# Epoch 10/10 Iteration: 72000 Avg. Training loss: 4.0086 0.0209 sec/batch
# Nearest to four: three, one, five, two, six, zero, seven, nine,
# Nearest to has: been, is, since, its, have, it, although, recently,
# Nearest to its: has, the, it, is, an, a, of, s,
# Nearest to one: four, three, two, nine, seven, six, eight, five,
# Nearest to who: whom, people, themselves, by, members, those, had, that,
# Nearest to was: later, first, had, after, as, a, became, this,
# Nearest to all: are, of, and, separate, most, other, only, together,
# Nearest to into: then, entered, out, through, which, and, a, finally,
# Nearest to issue: issues, since, accept, whether, contentious, uncomfortable, banknotes, january,
# Nearest to egypt: sinai, pressing, caesarion, egyptian, papandreou, ethiopian, tyre, fronting,
# Nearest to police: rassemblement, armed, gestapo, officers, paramilitary, petrograd, udall, militare,
# Nearest to test: tests, testing, matches, ban, intercontinental, rounders, postulated, wetlands,
# Nearest to orthodox: orthodoxy, blankets, ceti, pontryagin, hussar, eastern, dist, archdeacon,
# Nearest to san: francisco, diego, california, bernardino, jose, chargers, antonio, rectal,
# Nearest to shows: show, shown, showcase, ccm, showing, sketch, mostly, pisano,
# Nearest to powers: executive, authority, averting, historicism, raeder, othon, lafayette, arrestor,
# Epoch 10/10 Iteration: 72100 Avg. Training loss: 4.0112 0.0218 sec/batch
# Epoch 10/10 Iteration: 72200 Avg. Training loss: 3.9802 0.0208 sec/batch
# Epoch 10/10 Iteration: 72300 Avg. Training loss: 4.0336 0.0208 sec/batch
# Epoch 10/10 Iteration: 72400 Avg. Training loss: 4.0232 0.0208 sec/batch
# Epoch 10/10 Iteration: 72500 Avg. Training loss: 4.0460 0.0210 sec/batch
# Epoch 10/10 Iteration: 72600 Avg. Training loss: 4.0430 0.0207 sec/batch
# Epoch 10/10 Iteration: 72700 Avg. Training loss: 4.0878 0.0209 sec/batch
# Epoch 10/10 Iteration: 72800 Avg. Training loss: 3.9910 0.0209 sec/batch
# Epoch 10/10 Iteration: 72900 Avg. Training loss: 4.0251 0.0208 sec/batch
# Epoch 10/10 Iteration: 73000 Avg. Training loss: 4.0651 0.0208 sec/batch
# Nearest to four: three, one, five, six, two, seven, nine, zero,
# Nearest to has: been, is, since, have, its, although, it, recently,
# Nearest to its: has, the, it, is, an, itself, a, s,
# Nearest to one: nine, four, seven, two, three, six, eight, five,
# Nearest to who: people, whom, by, themselves, had, macdowell, that, them,
# Nearest to was: later, had, first, after, a, as, became, he,
# Nearest to all: are, and, separate, of, most, other, together, these,
# Nearest to into: entered, then, out, which, and, a, finally, through,
# Nearest to issue: issues, january, comics, magazines, uncomfortable, pg, crossovers, timepiece,
# Nearest to egypt: sinai, pressing, papandreou, caesarion, egyptian, ethiopian, saudi, champ,
# Nearest to police: gestapo, rassemblement, armed, officers, udall, militare, paramilitary, petrograd,
# Nearest to test: tests, testing, matches, ban, postulated, rounders, intercontinental, prentice,
# Nearest to orthodox: orthodoxy, blankets, ceti, eastern, pontryagin, archdeacon, dist, filioque,
# Nearest to san: francisco, diego, california, bernardino, jose, chargers, antonio, rectal,
# Nearest to shows: show, shown, showing, sketch, pisano, showcase, ccm, trakai,
# Nearest to powers: executive, averting, historicism, raeder, othon, authority, lafayette, arrestor,
# Epoch 10/10 Iteration: 73100 Avg. Training loss: 4.0952 0.0217 sec/batch
# Epoch 10/10 Iteration: 73200 Avg. Training loss: 4.0905 0.0209 sec/batch
# Epoch 10/10 Iteration: 73300 Avg. Training loss: 3.9712 0.0207 sec/batch
# Epoch 10/10 Iteration: 73400 Avg. Training loss: 4.0136 0.0207 sec/batch
# Epoch 10/10 Iteration: 73500 Avg. Training loss: 4.0668 0.0208 sec/batch
# Epoch 10/10 Iteration: 73600 Avg. Training loss: 4.0235 0.0208 sec/batch
# Epoch 10/10 Iteration: 73700 Avg. Training loss: 4.0710 0.0207 sec/batch
# Epoch 10/10 Iteration: 73800 Avg. Training loss: 4.0351 0.0208 sec/batch
# Epoch 10/10 Iteration: 73900 Avg. Training loss: 4.0376 0.0209 sec/batch
# Epoch 10/10 Iteration: 74000 Avg. Training loss: 4.0910 0.0207 sec/batch
# Nearest to four: three, five, one, six, two, nine, seven, zero,
# Nearest to has: been, is, since, its, have, it, recently, although,
# Nearest to its: has, the, is, it, s, a, itself, an,
# Nearest to one: nine, seven, three, eight, four, six, two, five,
# Nearest to who: whom, people, wftu, had, themselves, members, by, unmibh,
# Nearest to was: later, had, first, a, as, became, after, in,
# Nearest to all: are, and, separate, of, together, other, most, these,
# Nearest to into: entered, then, out, through, which, finally, a, and,
# Nearest to issue: issues, january, compromise, comics, pg, uncomfortable, magazines, accept,
# Nearest to egypt: sinai, pressing, egyptian, saudi, ethiopian, caesarion, papandreou, egyptians,
# Nearest to police: gestapo, armed, rassemblement, officers, paramilitary, militare, petrograd, military,
# Nearest to test: tests, testing, matches, ban, intercontinental, rounders, postulated, wetlands,
# Nearest to orthodox: orthodoxy, eastern, blankets, archdeacon, churches, pontryagin, synod, ceti,
# Nearest to san: francisco, diego, california, bernardino, jose, antonio, chargers, rectal,
# Nearest to shows: show, shown, showing, sketch, pisano, showcase, ccm, sitcoms,
# Nearest to powers: executive, averting, raeder, authority, othon, lafayette, historicism, heading,
# Epoch 10/10 Iteration: 74100 Avg. Training loss: 3.9876 0.0217 sec/batch
# Epoch 10/10 Iteration: 74200 Avg. Training loss: 4.0512 0.0208 sec/batch
# Epoch 10/10 Iteration: 74300 Avg. Training loss: 3.9814 0.0209 sec/batch
# Epoch 10/10 Iteration: 74400 Avg. Training loss: 4.0439 0.0207 sec/batch
# Epoch 10/10 Iteration: 74500 Avg. Training loss: 4.0510 0.0209 sec/batch
# Epoch 10/10 Iteration: 74600 Avg. Training loss: 4.0769 0.0209 sec/batch
# Epoch 10/10 Iteration: 74700 Avg. Training loss: 4.0809 0.0210 sec/batch
# Epoch 10/10 Iteration: 74800 Avg. Training loss: 3.9978 0.0209 sec/batch
# Epoch 10/10 Iteration: 74900 Avg. Training loss: 4.0577 0.0208 sec/batch
# Epoch 10/10 Iteration: 75000 Avg. Training loss: 4.0266 0.0207 sec/batch
# Nearest to four: three, five, one, six, two, nine, seven, zero,
# Nearest to has: been, since, is, its, have, it, recently, although,
# Nearest to its: the, has, it, of, s, is, an, in,
# Nearest to one: nine, seven, four, three, eight, two, six, five,
# Nearest to who: whom, people, by, them, themselves, had, their, those,
# Nearest to was: had, later, first, after, became, a, in, as,
# Nearest to all: are, and, separate, of, these, other, most, together,
# Nearest to into: then, entered, and, out, which, finally, the, a,
# Nearest to issue: issues, january, comics, compromise, accept, pg, magazines, whether,
# Nearest to egypt: sinai, egyptian, pressing, caesarion, ethiopian, papandreou, saudi, egyptians,
# Nearest to police: gestapo, armed, rassemblement, officers, paramilitary, militare, military, petrograd,
# Nearest to test: tests, testing, matches, ban, intercontinental, postulated, rounders, wetlands,
# Nearest to orthodox: orthodoxy, blankets, eastern, archdeacon, ceti, dist, pontryagin, filioque,
# Nearest to san: francisco, diego, california, bernardino, jose, chargers, rectal, antonio,
# Nearest to shows: show, shown, sketch, showing, sitcoms, trakai, unassigned, pisano,
# Nearest to powers: averting, executive, raeder, authority, othon, lafayette, historicism, coronets,
# Epoch 10/10 Iteration: 75100 Avg. Training loss: 4.0774 0.0218 sec/batch
# Epoch 10/10 Iteration: 75200 Avg. Training loss: 4.0526 0.0208 sec/batch
# Epoch 10/10 Iteration: 75300 Avg. Training loss: 4.0272 0.0212 sec/batch
# Epoch 10/10 Iteration: 75400 Avg. Training loss: 3.9788 0.0209 sec/batch
# Epoch 10/10 Iteration: 75500 Avg. Training loss: 4.0367 0.0208 sec/batch
# Epoch 10/10 Iteration: 75600 Avg. Training loss: 4.0216 0.0209 sec/batch
# Epoch 10/10 Iteration: 75700 Avg. Training loss: 4.0701 0.0209 sec/batch
# Epoch 10/10 Iteration: 75800 Avg. Training loss: 3.9254 0.0209 sec/batch
# Epoch 10/10 Iteration: 75900 Avg. Training loss: 4.0170 0.0209 sec/batch
# Epoch 10/10 Iteration: 76000 Avg. Training loss: 4.0977 0.0208 sec/batch
# Nearest to four: three, five, one, six, two, nine, seven, zero,
# Nearest to has: been, since, is, have, it, its, recently, although,
# Nearest to its: has, the, it, is, an, itself, s, a,
# Nearest to one: nine, seven, three, four, two, eight, six, five,
# Nearest to who: whom, people, themselves, by, had, them, those, members,
# Nearest to was: had, later, as, a, first, he, after, in,
# Nearest to all: are, and, other, separate, of, these, most, together,
# Nearest to into: entered, then, out, finally, a, and, through, the,
# Nearest to issue: january, issues, pg, compromise, magazine, november, contentious, since,
# Nearest to egypt: sinai, pressing, egyptian, caesarion, saudi, papandreou, ethiopian, mathematics,
# Nearest to police: gestapo, rassemblement, armed, officers, petrograd, paramilitary, militare, papillon,
# Nearest to test: tests, testing, matches, ban, intercontinental, rounders, postulated, wetlands,
# Nearest to orthodox: orthodoxy, blankets, eastern, ceti, dist, pontryagin, archdeacon, hussar,
# Nearest to san: francisco, diego, california, bernardino, jose, chargers, rectal, antonio,
# Nearest to shows: show, shown, sketch, sitcoms, pisano, showing, trakai, ccm,
# Nearest to powers: averting, raeder, executive, lafayette, othon, authority, heading, historicism,
# Epoch 10/10 Iteration: 76100 Avg. Training loss: 4.1231 0.0223 sec/batch
# Epoch 10/10 Iteration: 76200 Avg. Training loss: 4.1135 0.0210 sec/batch
# Epoch 10/10 Iteration: 76300 Avg. Training loss: 4.1215 0.0207 sec/batch
# Epoch 10/10 Iteration: 76400 Avg. Training loss: 4.0842 0.0207 sec/batch
# Epoch 10/10 Iteration: 76500 Avg. Training loss: 3.9672 0.0209 sec/batch
# Epoch 10/10 Iteration: 76600 Avg. Training loss: 4.0264 0.0207 sec/batch
# Epoch 10/10 Iteration: 76700 Avg. Training loss: 4.0082 0.0207 sec/batch
# Epoch 10/10 Iteration: 76800 Avg. Training loss: 4.0897 0.0207 sec/batch
# Epoch 10/10 Iteration: 76900 Avg. Training loss: 4.0172 0.0208 sec/batch
# Epoch 10/10 Iteration: 77000 Avg. Training loss: 3.8314 0.0207 sec/batch
# Nearest to four: three, five, one, six, two, nine, seven, zero,
# Nearest to has: been, since, is, its, although, have, it, an,
# Nearest to its: has, the, is, it, of, an, s, a,
# Nearest to one: nine, two, four, three, seven, eight, six, five,
# Nearest to who: whom, people, themselves, wftu, by, members, had, unmibh,
# Nearest to was: later, had, after, a, as, first, became, which,
# Nearest to all: are, separate, other, and, these, most, together, each,
# Nearest to into: entered, out, then, through, a, finally, the, which,
# Nearest to issue: january, issues, accept, compromise, pg, since, november, march,
# Nearest to egypt: sinai, pressing, egyptian, caesarion, papandreou, saudi, tyre, ethiopian,
# Nearest to police: armed, gestapo, rassemblement, officers, military, paramilitary, militare, petrograd,
# Nearest to test: tests, testing, ban, matches, postulated, rounders, wetlands, intercontinental,
# Nearest to orthodox: orthodoxy, blankets, ceti, hussar, dist, pontryagin, eastern, fixes,
# Nearest to san: francisco, diego, california, bernardino, jose, chargers, rectal, antonio,
# Nearest to shows: show, shown, sketch, sitcoms, ccm, nbc, showing, pisano,
# Nearest to powers: averting, executive, raeder, authority, othon, lafayette, heading, magical,
# Epoch 10/10 Iteration: 77100 Avg. Training loss: 4.0865 0.0218 sec/batch
# Epoch 10/10 Iteration: 77200 Avg. Training loss: 4.0067 0.0209 sec/batch
# Epoch 10/10 Iteration: 77300 Avg. Training loss: 4.0442 0.0209 sec/batch
# Epoch 10/10 Iteration: 77400 Avg. Training loss: 4.0437 0.0209 sec/batch
# Epoch 10/10 Iteration: 77500 Avg. Training loss: 4.0547 0.0207 sec/batch
# Epoch 10/10 Iteration: 77600 Avg. Training loss: 4.0738 0.0208 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
